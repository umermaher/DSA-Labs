# %% [markdown]
# <a href="https://colab.research.google.com/github/umermaher/DSA-Labs/blob/main/20SW033_Lab05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#task1
import pandas as pd

# Create a Pandas Series that contains the distance of some planets from the Sun.
distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]
planets = ['Earth', 'Saturn', 'Mars', 'Venus', 'Jupiter']

# Create a Pandas Series using the above data, with the name of the planets as
# the index and the distance from the Sun as your data.
dist_planets = pd.Series(distance_from_sun, index=planets)

# Calculate the number of minutes it takes sunlight to reach each planet.
# Speed of light in units of 10^6 km/minute
speed_of_light = 18
time_light = dist_planets / speed_of_light

# Use Boolean indexing to select only those planets for which sunlight takes less
# than 40 minutes to reach them.
close_planets = dist_planets[time_light < 40]

print("Distances from Sun:")
print(dist_planets)
print("\nTime for sunlight to reach each planet:")
print(time_light)
print("\nPlanets where sunlight takes less than 40 minutes:")
print(close_planets)
# Out:
# Distances from Sun:
# Earth       149.6
# Saturn     1433.5
# Mars        227.9
# Venus       108.2
# Jupiter     778.6
# dtype: float64
#
# Time for sunlight to reach each planet:
# Earth       8.311111
# Saturn     79.638889
# Mars       12.661111
# Venus       6.011111
# Jupiter    43.255556
# dtype: float64
#
# Planets where sunlight takes less than 40 minutes:
# Earth    149.6
# Mars     227.9
# Venus    108.2
# dtype: float64

# %%
#task2
import pandas as pd
import numpy as np

# Since we will be working with ratings, we will set the precision of our
# dataframes to one decimal place.
pd.set_option('display.precision', 1)

# Create a Pandas DataFrame that contains the ratings some users have given to a
# series of books. The ratings given are in the range from 1 to 5, with 5 being
# the best score. The names of the books, the authors, and the ratings of each user
# are given below:
books = pd.Series(data=['Great Expectations', 'Of Mice and Men', 'Romeo and Juliet', 'The Time Machine', 'Alice in Wonderland'])
authors = pd.Series(data=['Charles Dickens', 'John Steinbeck', 'William Shakespeare', ' H. G. Wells', 'Lewis Carroll'])
user_1 = pd.Series(data=[3.2, np.nan, 2.5])
user_2 = pd.Series(data=[5., 1.3, 4.0, 3.8])
user_3 = pd.Series(data=[2.0, 2.3, np.nan, 4])
user_4 = pd.Series(data=[4, 3.5, 4, 5, 4.2])

# Create a dictionary with the data given above
dat = {'Author': authors, 'Book Title': books, 'User 1': user_1, 'User 2': user_2, 'User 3': user_3, 'User 4': user_4}

# Use the dictionary to create a Pandas DataFrame
book_ratings = pd.DataFrame(dat)

# Now replace all the NaN values in your DataFrame with the average rating in each column.
# Replace the NaN values in place.
average_ratings = book_ratings.mean()
book_ratings.fillna(average_ratings, inplace=True)

# Print the resulting DataFrame
print(book_ratings)
# Out:
#                 Author           Book Title  User 1  User 2  User 3  User 4
# 0      Charles Dickens   Great Expectations     3.2     5.0     2.0     4.0
# 1       John Steinbeck      Of Mice and Men     2.9     1.3     2.3     3.5
# 2  William Shakespeare     Romeo and Juliet     2.5     4.0     2.8     4.0
# 3          H. G. Wells     The Time Machine     2.9     3.8     4.0     5.0
# 4        Lewis Carroll  Alice in Wonderland     2.9     3.5     2.8     4.2
# <ipython-input-2-ca5140bc3be0>:28: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   average_ratings = book_ratings.mean()

# %%
# We import pandas into Python
import pandas as pd

# We read in a stock data data file into a data frame and see what it looks like
df = pd.read_csv('./GOOG.csv')

# We display the first 5 rows of the DataFrame
df.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2004-08-19  49.7  51.7  47.7   49.8       49.8  44994500
# 1  2004-08-20  50.2  54.2  49.9   53.8       53.8  23005800
# 2  2004-08-23  55.0  56.4  54.2   54.3       54.3  18393200
# 3  2004-08-24  55.3  55.4  51.5   52.1       52.1  15361800
# 4  2004-08-25  52.1  53.7  51.6   52.7       52.7   9257400

# %%
import pandas as pd

# Load Google stock data
google_stock = pd.read_csv('GOOG.csv', usecols=['Date', 'Adj Close'], index_col='Date', parse_dates=True)

# Load Apple stock data
apple_stock = pd.read_csv('AAPL.csv', usecols=['Date', 'Adj Close'], index_col='Date', parse_dates=True)

# Load Amazon stock data
amazon_stock = pd.read_csv('AMZN.csv', usecols=['Date', 'Adj Close'], index_col='Date', parse_dates=True)

# %%
# We display the google_stock DataFrame
google_stock.head()
# Out:
#             Adj Close
# Date
# 2004-08-19       49.8
# 2004-08-20       53.8
# 2004-08-23       54.3
# 2004-08-24       52.1
# 2004-08-25       52.7

# %%
# We create calendar dates between '2000-01-01' and  '2016-12-31'
dates = pd.date_range('2000-01-01', '2016-12-31')

# We create and empty DataFrame that uses the above dates as indices
all_stocks = pd.DataFrame(index = dates)

# %%
# We join the Google stock to all_stocks
all_stocks = all_stocks.join(google_stock)

# We join the Apple stock to all_stocks
all_stocks = all_stocks.join(apple_stock)

# We join the Amazon stock to all_stocks
all_stocks = all_stocks.join(amazon_stock)

# %%
# We display the google_stock DataFrame
all_stocks.head()
# Out:
#             Adj Close
# 2000-01-01        NaN
# 2000-01-02        NaN
# 2000-01-03        NaN
# 2000-01-04        NaN
# 2000-01-05        NaN

# %%
# this allows plots to be rendered in the notebook
# %matplotlib inline

# We import matplotlib into Python
import matplotlib.pyplot as plt


# We plot the Google stock data
plt.plot(all_stocks['Google'])

# We plot the rolling mean ontop of our Google stock data
plt.plot(rollingMean)
plt.legend(['Google Stock Price', 'Rolling Mean'])
plt.show()
