# %% [markdown]
# <a href="https://colab.research.google.com/github/umermaher/DSA-Labs/blob/main/Lab12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

r = requests.get("https://medium.com/@mrmas918/title-unveiling-the-power-of-synthetic-financial-datasets-for-fraud-detection-4b0875dbdd7c")
r.text
# Out:
# '<!doctype html><html lang="en"><head><title data-rh="true">Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection | by Mrmas | Oct, 2023 | Medium</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" co
# ...

# %%
import re

#Removal of HTML tags using reqular expression
pattern = re.compile(r'<.*?>')
pattern.sub(' ',r.text)
# Out:
# '    Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection | by Mrmas | Oct, 2023 | Medium                                                     {"@context":"http:\\u002F\\u002Fschema.org","@type":"NewsArticle","image":{"@type":"ImageObject","url":"https:\\u002F\\u002Fmiro.medium.com\\u002Fv2\\u002F1*kFrc4tBFM_tCis-2Ic87WA.png","height":810,"width":1440},"url":"https:\\u002F\\u002Fmedium.com\\u002F@mrmas918\\u002Ftitle-unveiling-the-power-of-synthetic-financial-datasets-for-fraud-detection-4b0875dbdd7c","dateCreated":"2023-10-08T12:39:30.939Z","datePublished":"2023-10-08T12:39:30.939Z","dateModified":"2023-10-08T12:39:39.614Z","headline":"Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection","name":"Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection","description":"In the dynamic world of financial services, staying one step ahead of fraudsters is a top priority. Fraud detection systems are essential for saf
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html5lib')
soup.get_text()
# Out:
# 'Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection | by Mrmas | Oct, 2023 | Medium{"@context":"http:\\u002F\\u002Fschema.org","@type":"NewsArticle","image":{"@type":"ImageObject","url":"https:\\u002F\\u002Fmiro.medium.com\\u002Fv2\\u002F1*kFrc4tBFM_tCis-2Ic87WA.png","height":810,"width":1440},"url":"https:\\u002F\\u002Fmedium.com\\u002F@mrmas918\\u002Ftitle-unveiling-the-power-of-synthetic-financial-datasets-for-fraud-detection-4b0875dbdd7c","dateCreated":"2023-10-08T12:39:30.939Z","datePublished":"2023-10-08T12:39:30.939Z","dateModified":"2023-10-08T12:39:39.614Z","headline":"Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection","name":"Title: Unveiling the Power of Synthetic Financial Datasets for Fraud Detection","description":"In the dynamic world of financial services, staying one step ahead of fraudsters is a top priority. Fraud detection systems are essential for safeguarding financial transactions and maintaining…","ident
# ...

# %%
# Find all articles
summaries = soup.find_all("p", class_="pw-post-body-paragraph km kn ev ko b kp kq kr ks kt ku kv kw kx ky kz la lb lc ld le lf lg lh li lj eo bj")
summaries[0]
# Out:
# <p class="pw-post-body-paragraph km kn ev ko b kp kq kr ks kt ku kv kw kx ky kz la lb lc ld le lf lg lh li lj eo bj" id="6aee">In the dynamic world of financial services, staying one step ahead of fraudsters is a top priority. Fraud detection systems are essential for safeguarding financial transactions and maintaining trust. However, one significant challenge faced by researchers and data scientists is the lack of publicly available financial datasets, especially of mobile money transactions. The inherent privacy and sensitivity of financial data have traditionally made it challenging to access such datasets. In response to this issue, a solution has emerged: synthetic financial datasets.</p>

# %%
summaries[0].get_text().strip()
# Out:
# 'In the dynamic world of financial services, staying one step ahead of fraudsters is a top priority. Fraud detection systems are essential for safeguarding financial transactions and maintaining trust. However, one significant challenge faced by researchers and data scientists is the lack of publicly available financial datasets, especially of mobile money transactions. The inherent privacy and sensitivity of financial data have traditionally made it challenging to access such datasets. In response to this issue, a solution has emerged: synthetic financial datasets.'

# %%
text = summaries[0].get_text().strip().lower()
text
# Out:
# 'in the dynamic world of financial services, staying one step ahead of fraudsters is a top priority. fraud detection systems are essential for safeguarding financial transactions and maintaining trust. however, one significant challenge faced by researchers and data scientists is the lack of publicly available financial datasets, especially of mobile money transactions. the inherent privacy and sensitivity of financial data have traditionally made it challenging to access such datasets. in response to this issue, a solution has emerged: synthetic financial datasets.'

# %%
# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text)
print(text)
# Out:
# in the dynamic world of financial services  staying one step ahead of fraudsters is a top priority  fraud detection systems are essential for safeguarding financial transactions and maintaining trust  however  one significant challenge faced by researchers and data scientists is the lack of publicly available financial datasets  especially of mobile money transactions  the inherent privacy and sensitivity of financial data have traditionally made it challenging to access such datasets  in response to this issue  a solution has emerged  synthetic financial datasets

# %% [markdown]
# # Tokenization

# %%
words = text.split()
words
# Out:
# ['in',
#  'the',
#  'dynamic',
#  'world',
#  'of',
#  'financial',
#  'services',
#  'staying',
#  'one',
#  'step',
#  'ahead',
#  'of',
#  'fraudsters',
#  'is',
#  'a',
#  'top',
#  'priority',
#  'fraud',
#  'detection',
#  'systems',
#  'are',
#  'essential',
#  'for',
#  'safeguarding',
#  'financial',
#  'transactions',
#  'and',
#  'maintaining',
#  'trust',
#  'however',
#  'one',
#  'significant',
#  'challenge',
#  'faced',
#  'by',
#  'researchers',
#  'and',
#  'data',
#  'scientists',
#  'is',
#  'the',
#  'lack',
#  'of',
#  'publicly',
#  'available',
#  'financial',
#  'datasets',
#  'especially',
#  'of',
#  'mobile',
#  'money',
#  'transactions',
#  'the',
#  'inherent',
#  'privacy',
#  'and',
#  'sensitivity',
#  'of',
#  'financial',
#  'data',
#  'have',
#  'traditionally',
#  'made',
#  'it',
#  'challenging',
#  'to',
#  'access',
#  'such',
#  'datasets',
#  'in',
#  'response',
#  'to',
#  'this',
#  'issue',
#  'a',
#  'solution',
#  'has',
# ...

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['in', 'the', 'dynamic', 'world', 'of', 'financial', 'services', 'staying', 'one', 'step', 'ahead', 'of', 'fraudsters', 'is', 'a', 'top', 'priority', 'fraud', 'detection', 'systems', 'are', 'essential', 'for', 'safeguarding', 'financial', 'transactions', 'and', 'maintaining', 'trust', 'however', 'one', 'significant', 'challenge', 'faced', 'by', 'researchers', 'and', 'data', 'scientists', 'is', 'the', 'lack', 'of', 'publicly', 'available', 'financial', 'datasets', 'especially', 'of', 'mobile', 'money', 'transactions', 'the', 'inherent', 'privacy', 'and', 'sensitivity', 'of', 'financial', 'data', 'have', 'traditionally', 'made', 'it', 'challenging', 'to', 'access', 'such', 'datasets', 'in', 'response', 'to', 'this', 'issue', 'a', 'solution', 'has', 'emerged', 'synthetic', 'financial', 'datasets']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['in the dynamic world of financial services  staying one step ahead of fraudsters is a top priority  fraud detection systems are essential for safeguarding financial transactions and maintaining trust  however  one significant challenge faced by researchers and data scientists is the lack of publicly available financial datasets  especially of mobile money transactions  the inherent privacy and sensitivity of financial data have traditionally made it challenging to access such datasets  in response to this issue  a solution has emerged  synthetic financial datasets']

# %%
# List stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
words
# Out:
# ['in',
#  'the',
#  'dynamic',
#  'world',
#  'of',
#  'financial',
#  'services',
#  'staying',
#  'one',
#  'step',
#  'ahead',
#  'of',
#  'fraudsters',
#  'is',
#  'a',
#  'top',
#  'priority',
#  'fraud',
#  'detection',
#  'systems',
#  'are',
#  'essential',
#  'for',
#  'safeguarding',
#  'financial',
#  'transactions',
#  'and',
#  'maintaining',
#  'trust',
#  'however',
#  'one',
#  'significant',
#  'challenge',
#  'faced',
#  'by',
#  'researchers',
#  'and',
#  'data',
#  'scientists',
#  'is',
#  'the',
#  'lack',
#  'of',
#  'publicly',
#  'available',
#  'financial',
#  'datasets',
#  'especially',
#  'of',
#  'mobile',
#  'money',
#  'transactions',
#  'the',
#  'inherent',
#  'privacy',
#  'and',
#  'sensitivity',
#  'of',
#  'financial',
#  'data',
#  'have',
#  'traditionally',
#  'made',
#  'it',
#  'challenging',
#  'to',
#  'access',
#  'such',
#  'datasets',
#  'in',
#  'response',
#  'to',
#  'this',
#  'issue',
#  'a',
#  'solution',
#  'has',
# ...

# %%
wordsExceptStopWords = [w for w in words if w not in stopwords.words("english")]
wordsExceptStopWords
# Out:
# ['dynamic',
#  'world',
#  'financial',
#  'services',
#  'staying',
#  'one',
#  'step',
#  'ahead',
#  'fraudsters',
#  'top',
#  'priority',
#  'fraud',
#  'detection',
#  'systems',
#  'essential',
#  'safeguarding',
#  'financial',
#  'transactions',
#  'maintaining',
#  'trust',
#  'however',
#  'one',
#  'significant',
#  'challenge',
#  'faced',
#  'researchers',
#  'data',
#  'scientists',
#  'lack',
#  'publicly',
#  'available',
#  'financial',
#  'datasets',
#  'especially',
#  'mobile',
#  'money',
#  'transactions',
#  'inherent',
#  'privacy',
#  'sensitivity',
#  'financial',
#  'data',
#  'traditionally',
#  'made',
#  'challenging',
#  'access',
#  'datasets',
#  'response',
#  'issue',
#  'solution',
#  'emerged',
#  'synthetic',
#  'financial',
#  'datasets']

# %%
# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['in', 'the', 'dynam', 'world', 'of', 'financi', 'servic', 'stay', 'one', 'step', 'ahead', 'of', 'fraudster', 'is', 'a', 'top', 'prioriti', 'fraud', 'detect', 'system', 'are', 'essenti', 'for', 'safeguard', 'financi', 'transact', 'and', 'maintain', 'trust', 'howev', 'one', 'signific', 'challeng', 'face', 'by', 'research', 'and', 'data', 'scientist', 'is', 'the', 'lack', 'of', 'publicli', 'avail', 'financi', 'dataset', 'especi', 'of', 'mobil', 'money', 'transact', 'the', 'inher', 'privaci', 'and', 'sensit', 'of', 'financi', 'data', 'have', 'tradit', 'made', 'it', 'challeng', 'to', 'access', 'such', 'dataset', 'in', 'respons', 'to', 'thi', 'issu', 'a', 'solut', 'ha', 'emerg', 'synthet', 'financi', 'dataset']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)

# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['in', 'the', 'dynamic', 'world', 'of', 'financial', 'service', 'staying', 'one', 'step', 'ahead', 'of', 'fraudsters', 'is', 'a', 'top', 'priority', 'fraud', 'detection', 'system', 'are', 'essential', 'for', 'safeguarding', 'financial', 'transaction', 'and', 'maintaining', 'trust', 'however', 'one', 'significant', 'challenge', 'faced', 'by', 'researcher', 'and', 'data', 'scientist', 'is', 'the', 'lack', 'of', 'publicly', 'available', 'financial', 'datasets', 'especially', 'of', 'mobile', 'money', 'transaction', 'the', 'inherent', 'privacy', 'and', 'sensitivity', 'of', 'financial', 'data', 'have', 'traditionally', 'made', 'it', 'challenging', 'to', 'access', 'such', 'datasets', 'in', 'response', 'to', 'this', 'issue', 'a', 'solution', 'ha', 'emerged', 'synthetic', 'financial', 'datasets']
# ...
